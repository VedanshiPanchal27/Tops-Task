# %%
# 1.Create a Python script called playlist_stats.py that takes a list of daily Spotify song play counts (e.g., [120, 135, 150, 200, 120, 90, 200]) and calculates the mean (average) number of plays.

# %%
# 2.Given the following array of delivery times (in minutes) for Zomato orders: [30, 25, 40, 35, 30, 45, 30], write code to find the median delivery time and print it.
delivery_times = [30, 25, 40, 35, 30, 45, 30]
sorted_times = sorted(delivery_times)
n = len(sorted_times)
median = sorted_times[n // 2]
print("Median delivery time:", median)
# Out:
# Median delivery time: 30

# %%
# 3.Write a function most_common_rating(ratings) that takes a list of Flipkart product ratings (e.g., [5, 4, 4, 3, 5, 4, 2, 4]) and returns the mode (most frequent rating).
def most_common_rating(ratings):
    return max(set(ratings), key=ratings.count)
    
ratings = [5, 4, 4, 3, 5, 4, 2, 4]
print("Most common rating:", most_common_rating(ratings))
# Out:
# Most common rating: 4

# %%
# 4.Given three lists representing YouTube video views for three different channels, compare the mean, median, and mode for each channel, and decide which channel's data is most affected by outliers.<br><br><em><strong>Hint:</strong> Try using one list with a very high value (e.g., [100, 120, 110, 105, 5000]) to see the effect on mean vs median.</em>
from statistics import mean, median, mode

channel1 = [100, 120, 110, 105, 5000]
channel2 = [100, 120, 110, 105, 115]
channel3 = [80, 90, 90, 100, 110]

channels = {
    "Channel 1": channel1,
    "Channel 2": channel2,
    "Channel 3": channel3
}

for name, views in channels.items():
    print("\n", name)
    print("Mean:", mean(views))
    print("Median:", median(views))
    print("Mode:", mode(views))

print("\nChannel 1 is most affected by the outlier 5000.")
# Out:
#  Channel 1
# Mean: 1087
# Median: 110
# Mode: 100
#
#  Channel 2
# Mean: 110
# Median: 110
# Mode: 100
#
#  Channel 3
# Mean: 94
# Median: 90
# Mode: 90
#
# Channel 1 is most affected by the outlier 5000.

# %%
pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-3.0.5-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\sp\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.5.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sp\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Collecting tzdata (from pandas)
#   Downloading tzdata-2026.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\sp\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.5-cp312-cp312-win_amd64.whl (9.8 MB)
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.8 MB 2.1 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.0/9.8 MB 1.9 MB/s eta 0:00:05
#    ------ --------------------------------- 1.6/9.8 MB 2.0 MB/s eta 0:00:05
#    ------- -------------------------------- 1.8/9.8 MB 2.0 MB/s eta 0:00:04
#    --------- ------------------------------ 2.4/9.8 MB 1.9 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.6/9.8 MB 1.9 MB/s eta 0:00:04
#    ------------- -------------------------- 3.4/9.8 MB 2.1 MB/s eta 0:00:04
#    --------------- ------------------------ 3.9/9.8 MB 2.2 MB/s eta 0:00:03
#    ------------------- -------------------- 4.7/9.8 MB 2.3 MB/s eta 0:00:03
#    ---------------------- ----------------- 5.5/9.8 MB 2.4 MB/s eta 0:00:02
#    ------------------------ --------------- 6.0/9.8 MB 2.5 MB/s eta 0:00:02
#    --------------------------- ------------ 6.8/9.8 MB 2.6 MB/s eta 0:00:02
#    ----------------------------- ---------- 7.3/9.8 MB 2.6 MB/s eta 0:00:01
#    ------------------------------- -------- 7.9/9.8 MB 2.6 MB/s eta 0:00:01
#    --------------------------------- ------ 8.1/9.8 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.4/9.8 MB 2.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.7/9.8 MB 2.4 MB/s eta 0:00:01
#    ------------------------------------- -- 9.2/9.8 MB 2.3 MB/s eta 0:00:01
#    -------------------------------------- - 9.4/9.8 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 2.2 MB/s eta 0:00:00
# Downloading tzdata-2026.3-py2.py3-none-any.whl (348 kB)
# Installing collected packages: tzdata, pandas
# Successfully installed pandas-3.0.5 tzdata-2026.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# 5.Pick any real dataset from Kaggle or UCI (e.g., IPL player runs, Swiggy restaurant ratings, or movie box office collections), load it using pandas, and display the mean, median, and mode for one numeric column of your choice.


# Example: Loading a dataset (replace with actual dataset path)
# df = pd.read_csv("your_dataset.csv")

# For demonstration, let's create a sample DataFrame
import pandas as pd
data = {
    "player_runs": [100, 150, 200, 250, 300],
    "restaurant_ratings": [4.5, 4.0, 3.5, 4.5, 4.0],
    "movie_box_office": [1000, 1500, 2000, 2500, 3000]
}
df = pd.DataFrame(data)

# Display statistics for one numeric column
column_name = "player_runs"
print(f"Mean {column_name}: {df[column_name].mean()}")
print(f"Median {column_name}: {df[column_name].median()}")
print(f"Mode {column_name}: {df[column_name].mode().iloc[0]}")
# Out:
# Mean player_runs: 200.0
# Median player_runs: 200.0
# Mode player_runs: 100
