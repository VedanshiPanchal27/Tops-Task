# %%
# 1.List 3 examples of 'population' and 'sample' in the context of apps you use daily (like Instagram followers, Zomato restaurants, or Flipkart products). For each, clearly define what would be considered the population and what would be a sample.
# Example 1: Instagram followers
# Suppose you want to study the followers of an Instagram account.
# Population: All 10,000 followers of the account.
# Sample: 500 followers selected from those 10,000 followers.
# Example 2: Zomato restaurants
# Suppose you want to study restaurant ratings.
# Population: All restaurants listed on Zomato in Ahmedabad.
# Sample: 100 restaurants randomly selected from those restaurants.
# Example 3: Flipkart products
# Suppose you want to study customer ratings of electronic products.
# Population: All electronic products listed on Flipkart.
# Sample: 200 electronic products selected for the study.

# %%
# 2.Write a Python script that simulates random sampling: given a list of 1000 fake user IDs (e.g., user1 to user1000), select 50 random users to simulate a survey sample. Print the selected user IDs.<br><br><em><strong>Hint:</strong> Use the random.sample() function from Python's random module.</em>
import random

users = [f"user{i}" for i in range(1, 1001)]

sample_users = random.sample(users, 50)

print(sample_users)
# Out:
# ['user653', 'user33', 'user292', 'user6', 'user985', 'user140', 'user754', 'user997', 'user416', 'user468', 'user617', 'user313', 'user853', 'user287', 'user682', 'user32', 'user134', 'user361', 'user825', 'user4', 'user492', 'user940', 'user639', 'user705', 'user434', 'user611', 'user422', 'user73', 'user410', 'user356', 'user411', 'user341', 'user638', 'user566', 'user374', 'user589', 'user761', 'user388', 'user662', 'user278', 'user522', 'user305', 'user473', 'user250', 'user806', 'user584', 'user540', 'user54', 'user615', 'user545']

# %%
# 3.Imagine you are analyzing food delivery times on Swiggy. Explain in 2-3 sentences why you would use sampling instead of collecting data from every single order ever made.
# Suppose Swiggy has millions of orders. Collecting and analyzing every single order would require a lot of time, storage, and processing.
# Instead, we can select a smaller sample of orders and analyze their delivery times. If the sample is properly selected, it can give us a good idea about the delivery times of all orders.

# %%
# 4.Given this scenario: A survey about music preferences is only sent to users who recently streamed Bollywood songs on Spotify. Identify and explain the type of bias this introduces in the sample.
# The survey is sent only to users who recently streamed Bollywood songs.
# This creates selection bias.
# Why?
# Spotify has many different types of listeners:
# Bollywood music listeners
# English music listeners
# Punjabi music listeners
# Classical music listeners
# Rock/pop listeners, etc.
# But the survey only includes people who recently listened to Bollywood songs.
# Therefore, the sample does not properly represent all Spotify users.

# %%
# 5.Choose any two types of sampling (for example: random sampling, stratified sampling, systematic sampling, cluster sampling). For each, describe how you would use it to select a sample of users from BookMyShow to study movie booking habits.
# A. Random Sampling
# Suppose BookMyShow has 100,000 users.
# We randomly select 1,000 users from the entire user population.
# Every user has an equal chance of being selected.
# How to say it:
# "In random sampling, I would randomly select 1,000 BookMyShow users from all users. Every user would have an equal chance of being selected, and then I would study their movie booking habits."
# B. Stratified Sampling
# Here, we first divide users into groups, called strata.
# For example:
# 18–25 years
# 26–35 years
# 36–50 years
# 51+ years
# Then we select users from each group.
# For example, if we need 1,000 users, we could select an appropriate number from each age group.
