# %%
# 1.List 5 daily actions you perform on apps like Instagram, Zomato, or Flipkart, and for each, identify whether the data generated is numerical or categorical.
actions = [
    ("Instagram - Number of likes", "Numerical"),
    ("Instagram - Type of post (photo/reel/video)", "Categorical"),
    ("Zomato - Restaurant rating", "Numerical"),
    ("Flipkart - Product category", "Categorical"),
    ("Flipkart - Product price", "Numerical")
]

print("1. Daily Actions and Data Types:")
for action, data_type in actions:
    print(f"{action}: {data_type}")
# Out:
# 1. Daily Actions and Data Types:
# Instagram - Number of likes: Numerical
# Instagram - Type of post (photo/reel/video): Categorical
# Zomato - Restaurant rating: Numerical
# Flipkart - Product category: Categorical
# Flipkart - Product price: Numerical

# %%
# 2.Given this sample data from a music app: ['Pop', 'Rock', 'Jazz', 'Hip-Hop', 'Pop', 'Rock', 'Jazz', 'Pop'], classify the type of data and explain your reasoning in 2-3 lines.
music_data = ['Pop', 'Rock', 'Jazz', 'Hip-Hop', 'Pop', 'Rock', 'Jazz', 'Pop']

print("\n2. Music Data:")
print("Data:", music_data)
print("Type: Categorical")
print("Reason: The data represents music genres, which are names or categories.")
print("They do not represent numerical measurements.")
# Out:
# 2. Music Data:
# Data: ['Pop', 'Rock', 'Jazz', 'Hip-Hop', 'Pop', 'Rock', 'Jazz', 'Pop']
# Type: Categorical
# Reason: The data represents music genres, which are names or categories.
# They do not represent numerical measurements.

# %%
# 3.Pick any one feature from an app you use (such as the number of likes on an Instagram post, or the rating of a restaurant on Zomato) and describe how statistics could help improve that feature for users.
likes = [10, 15, 20, 25, 30, 18, 22]

mean_likes = sum(likes) / len(likes)

print("\n3. Statistics and Likes:")
print("Average number of likes:", mean_likes)
print("Statistics can help find the average number of likes.")
print("This can help an app recommend popular posts and improve the user's feed.")
# Out:
# 3. Statistics and Likes:
# Average number of likes: 20.0
# Statistics can help find the average number of likes.
# This can help an app recommend popular posts and improve the user's feed.

# %%
# 4.Suppose you are building a new playlist recommendation feature for a Spotify-like app. List 3 basic statistical terms (such as mean, median, mode, variance, etc.) that would be useful in analyzing user listening data, and explain each with a one-line example.
listening_minutes = [30, 45, 60, 45, 90, 30, 45]

# Mean
mean = sum(listening_minutes) / len(listening_minutes)

# Median
sorted_data = sorted(listening_minutes)
n = len(sorted_data)
median = sorted_data[n // 2]

# Mode
mode = max(set(listening_minutes), key=listening_minutes.count)

print("\n4. Statistical Terms:")
print("Mean:", mean, "- Average listening time of users.")
print("Median:", median, "- Middle listening time when data is arranged.")
print("Mode:", mode, "- Most common listening time.")
# Out:
# 4. Statistical Terms:
# Mean: 49.285714285714285 - Average listening time of users.
# Median: 45 - Middle listening time when data is arranged.
# Mode: 45 - Most common listening time.
