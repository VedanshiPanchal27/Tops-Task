# %% [markdown]
# #task 1
# Null hypothesis: People do not spend more time on Instagram than YouTube.
#
# Alternative hypothesis: People spend more time on Instagram than YouTube.

# %%
#task 2

# %%
#task 3

# %%
#task 4
