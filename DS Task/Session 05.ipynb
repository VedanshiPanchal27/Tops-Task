# %%
# 1.Create a list called playlist_ids with 5 song IDs (as integers) that you might see in a Spotify playlist, and print the list.
playlist_ids = [27056, 19101, 27197, 20157]
print(playlist_ids)
# Out:
# [27056, 19101, 27197, 20157]

# %%
# 2.Add two more song IDs to your playlist_ids list using both append() and extend(), then print the updated list.<br><br><em><strong>Hint:</strong> Use append() for a single ID and extend() for adding multiple IDs at once.</em>
playlist_ids.append(19051)
playlist_ids.extend([19052, 19053])
print(playlist_ids)
# Out:
# [27056, 19101, 27197, 20157, 19051, 19052, 19053]

# %%
# 3.Simulate removing the last played song from your playlist_ids list using pop(), and display the removed ID along with the remaining playlist.
playlist_ids.pop()
# Out:
# 19053

# %%
# 4.Create a tuple called insta_filters with 4 Instagram filter names (as strings). Try to change the first filter name and observe what error you get.<br><br><em><strong>Hint:</strong> Tuples are immutable. Note down the error message.</em>
insta_filters = ("Clarendon", "Gingham", "Juno", "Lark")
insta_filters[0] = "Moon"  # This will raise a TypeError
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 # 4.Create a tuple called insta_filters with 4 Instagram filter names (as strings). Try to change the first filter name and observe what error you get.<br><br><em><strong>Hint:</strong> Tuples are immutable. Note down the error message.</em>
#       2 insta_filters = ("Clarendon", "Gingham", "Juno", "Lark")
# ----> 3 insta_filters[0] = "Moon"  # This will raise a TypeError
#
# TypeError: 'tuple' object does not support item assignment

# %%
# 5.Write a short Python script that takes a scenario (like a list of recent Zomato orders vs a tuple of fixed IPL team names) and prints which one should use a list and which should use a tuple, explaining your choice in a comment.

# Scenario 1: List of recent Zomato orders (mutable)
recent_orders = ["Pizza", "Burger", "Pasta"]
print("For recent Zomato orders, use a list because the order can change.")

# Scenario 2: Fixed IPL team names (immutable)
ipl_teams = ("Mumbai Indians", "Chennai Super Kings", "Royal Challengers Bangalore")
print("For fixed IPL team names, use a tuple because the teams don't change.")
# Out:
# For recent Zomato orders, use a list because the order can change.
# For fixed IPL team names, use a tuple because the teams don't change.
