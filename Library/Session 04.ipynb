# %%
pip install pandas openpyxl
# Out:
# Requirement already satisfied: pandas in c:\users\sp\appdata\local\programs\python\python312\lib\site-packages (3.0.5)
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\sp\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.5.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sp\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\sp\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2026.3)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: six>=1.5 in c:\users\sp\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# 1.Download a sample CSV file of IPL cricket match scores from Kaggle or any public dataset, and use pd.read_csv() to load it into a DataFrame. Print the first 5 rows to verify the data.
import pandas as pd

# Load CSV file
df = pd.read_csv("ipl_matches.csv")

# Print first 5 rows
print(df.head())
# Out:
#        id  season       city        date                        team1  \
# 0       1    2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1       2    2017       Pune  06-04-2017               Mumbai Indians
# 2       3    2017     Rajkot  07-04-2017                Gujarat Lions
# 3       4    2017     Indore  08-04-2017       Rising Pune Supergiant
# 4       5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2
# 0  Royal Challengers Bangalore
# 1       Rising Pune Supergiant
# 2               Mumbai Indians
# 3          Sunrisers Hyderabad
# 4                Gujarat Lions

# %%
# 2.Find a small JSON dataset of trending songs (for example, from Spotify's API samples or any open JSON file), and use pd.read_json() to import it into a DataFrame. Display the DataFrame's column names and data types using df.info().
import pandas as pd
import json

# Open JSON file
with open("spotify_tracks.json", "r") as file:
    data = json.load(file)

# Convert to DataFrame
df = pd.DataFrame(data)

# Display column names and data types
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         5 non-null      str
#  1   artist       5 non-null      str
#  2   popularity   5 non-null      int64
#  3   duration_ms  5 non-null      int64
# dtypes: int64(2), str(2)
# memory usage: 292.0 bytes

# %%
# 3.You have a TSV (tab-separated values) file containing Zomato restaurant data. Use pd.read_csv() with the correct separator to load the data, and then use df.describe(include='all') to generate summary statistics.<br><br><em><strong>Hint:</strong> The separator for TSV files is '\t'.</em>
import pandas as pd

# Read TSV file
df = pd.read_csv("zomato_restaurants.tsv", sep="\t")

# Generate summary statistics
print(df.describe(include="all"))
# Out:
#        restaurant_name       city       cuisine    rating       votes
# count                5          5             5  5.000000    5.000000
# unique               5          3             5       NaN         NaN
# top       Zomato Spice  Ahmedabad  North Indian       NaN         NaN
# freq                 1          3             1       NaN         NaN
# mean               NaN        NaN           NaN  4.120000  310.000000
# std                NaN        NaN           NaN  0.258844   85.146932
# min                NaN        NaN           NaN  3.800000  190.000000
# 25%                NaN        NaN           NaN  4.000000  280.000000
# 50%                NaN        NaN           NaN  4.100000  310.000000
# 75%                NaN        NaN           NaN  4.200000  350.000000
# max                NaN        NaN           NaN  4.500000  420.000000

# %%
# 4.Download a large Excel file (at least 10,000 rows) of Flipkart product listings. Use pd.read_excel() with the chunksize parameter to read the file in chunks of 2000 rows, and print the number of rows in each chunk as you iterate.
import pandas as pd

# Read Excel file
df = pd.read_excel("flipkart_products_10001.xlsx")

# Chunk size
chunk_size = 2000

# Print number of rows in each chunk
for start in range(0, len(df), chunk_size):
    chunk = df.iloc[start:start + chunk_size]
    print("Rows in this chunk:", len(chunk))
# Out:
# Rows in this chunk: 2000
# Rows in this chunk: 2000
# Rows in this chunk: 2000
# Rows in this chunk: 2000
# Rows in this chunk: 2000
# Rows in this chunk: 1

# %%
# 5.Use ChatGPT or Copilot to generate a Python code snippet that reads a semicolon-separated CSV of Paytm transactions, detects missing values, and prints out which columns have nulls. Test the code with a small sample file and fix any errors you encounter.
import pandas as pd

# Read semicolon-separated CSV
df = pd.read_csv("paytm_transactions.csv", sep=";")

# Check for missing values
print("Missing values in each column:")
print(df.isnull().sum())

# Print only columns that contain null values
print("\nColumns having null values:")

null_columns = df.columns[df.isnull().any()]

for column in null_columns:
    print(column)
# Out:
# Missing values in each column:
# transaction_id    0
# amount            2
# status            1
# customer          1
# dtype: int64
#
# Columns having null values:
# amount
# status
# customer
