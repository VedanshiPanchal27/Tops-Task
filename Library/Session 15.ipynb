# %%
# 1.Install the pandas-profiling library and generate a profile report for the 'Spotify Top 100 Songs' dataset (CSV available on Kaggle); open the HTML report and note any missing values or data type issues.
# !pip install pandas-profiling
# Out:
# ...
#   Using cached pandas_profiling-3.2.0-py2.py3-none-any.whl.metadata (21 kB)
# ...
#   Using cached joblib-1.1.1-py2.py3-none-any.whl.metadata (5.2 kB)
# ...
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached MarkupSafe-2.1.5.tar.gz (19 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached visions-0.7.4-py3-none-any.whl.metadata (5.9 kB)
# ...
#   Using cached htmlmin-0.1.12.tar.gz (19 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
# ...

# %%
import pandas as pd
from pandas_profiling import ProfileReport

# Load Spotify dataset
df = pd.read_csv("spotify_top_100.csv")

# Create profile report
profile = ProfileReport(
    df,
    title="Spotify Top 100 Songs Profile Report",
    explorative=True
)

# Save report
profile.to_file("spotify_profile_report.html")

print("Profile report created successfully!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 import pandas as pd
# ----> 2 from pandas_profiling import ProfileReport
#       3
#       4 # Load Spotify dataset
#       5 df = pd.read_csv("spotify_top_100.csv")
#
# ModuleNotFoundError: No module named 'pandas_profiling'

# %%
# 2.Use Sweetviz to create a comparison report between two CSV files: one containing Zomato restaurant data for Mumbai and another for Delhi. Briefly describe one key difference you spot in the visual report.<br><br><em><strong>Hint:</strong> Use analyze() for single file and compare() for two datasets.</em>
# !pip install sweetviz
# Out:
# ...
#    ---------------------------------------- 0.0/15.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/15.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/15.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/15.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/15.1 MB 696.9 kB/s eta 0:00:21
#    -- ------------------------------------- 0.8/15.1 MB 696.9 kB/s eta 0:00:21
#    -- ------------------------------------- 1.0/15.1 MB 638.5 kB/s eta 0:00:23
#    ----- ---------------------------------- 2.1/15.1 MB 1.3 MB/s eta 0:00:11
#    -------- ------------------------------- 3.1/15.1 MB 1.7 MB/s eta 0:00:07
# ...

# %%
import pandas as pd
import sweetviz as sv

# Load Mumbai data
mumbai = pd.read_csv("zomato_mumbai.csv")

# Load Delhi data
delhi = pd.read_csv("zomato_delhi.csv")

# Create comparison report
report = sv.compare(
    [mumbai, "Mumbai"],
    [delhi, "Delhi"]
)

# Save report
report.show_html("zomato_mumbai_vs_delhi.html")

print("Sweetviz comparison report created!")

# %%
# 3.Open the Myntra product listings dataset in D-Tale, explore the interface, and use it to filter products with a price above ₹2000. Take a screenshot of the filtered view and note the number of such products.
# !pip install dtale
# Out:
# ...
#   Using cached dtale-3.22.0-py2.py3-none-any.whl.metadata (16 kB)
# ...
#   Using cached beautifulsoup4-4.15.0-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached dash-4.4.1-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached dash_bootstrap_components-2.0.4-py3-none-any.whl.metadata (18 kB)
# ...
#   Using cached flask-3.1.3-py3-none-any.whl.metadata (3.2 kB)
# ...
#   Using cached flask_compress-1.25-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached kaleido-1.4.0-py3-none-any.whl.metadata (7.5 kB)
# ...
#   Using cached missingno-0.5.2-py3-none-any.whl.metadata (639 bytes)
# ...
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached xarray-2026.7.0-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached importlib_metadata-9.0.1-py3-none-any.whl.metadata (4.5 kB)
# ...
#   Using cached choreographer-1.4.0-py3-none-any.whl.metadata (5.5 kB)
# ...
# Using cached dtale-3.22.0-py2.py3-none-any.whl (17.4 MB)
# Using cached beautifulsoup4-4.15.0-py3-none-any.whl (109 kB)
# ...

# %%
import pandas as pd
import dtale

# Load Myntra dataset
df = pd.read_csv("myntra_products.csv")

# Open D-Tale
d = dtale.show(df)

print(d.main_url())
# Out:
# http://WORK:40000/dtale/main/1
# None

# %%
# 4.Given a pandas-profiling report for a Flipkart product reviews dataset, interpret and list two columns that may need cleaning or transformation before further analysis.<br><br><em><strong>Hint:</strong> Look for columns with high cardinality, missing values, or warnings in the report.</em>
import pandas as pd
from ydata_profiling import ProfileReport

df = pd.read_csv("flipkart_reviews.csv")

profile = ProfileReport(
    df,
    title="Flipkart Reviews Report",
    explorative=True
)

profile.to_file("flipkart_reviews_report.html")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 3
#       1 # 4.Given a pandas-profiling report for a Flipkart product reviews dataset, interpret and list two columns that may need cleaning or transformation before further analysis.<br><br><em><strong>Hint:</strong> Look for columns with high cardinality, missing values, or warnings in the report.</em>
#       2 import pandas as pd
# ----> 3 from ydata_profiling import ProfileReport
#       4
#       5 df = pd.read_csv("flipkart_reviews.csv")
#       6
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\ydata_profiling\__init__.py:11
#       8 import importlib.util  # isort:skip # noqa
#       9 from warnings import warn
# ---> 11 from ydata_profiling.compare_reports import compare  # isort:skip # noqa
#      12 from ydata_profiling.controller import pandas_decorator  # isort:skip # noqa
# ...

# %%
# 5.Pick any one auto-EDA tool (pandas-profiling, Sweetviz, or D-Tale) and use ChatGPT or Copilot to generate a code snippet that loads a Swiggy food order CSV and produces a summary report. Run the code and attach the generated report or a screenshot as proof.
# !pip install pandas ydata-profiling

# %%
import pandas as pd
from ydata_profiling import ProfileReport

# Load Swiggy order data
df = pd.read_csv("swiggy_orders2.csv")

# Create profile report
profile = ProfileReport(
    df,
    title="Swiggy Food Orders - EDA Report",
    explorative=True
)

# Save report
profile.to_file("swiggy_eda_report.html")

print("Swiggy EDA report created successfully!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 from ydata_profiling import ProfileReport
#       3
#       4 # Load Swiggy order data
#       5 df = pd.read_csv("swiggy_orders2.csv")
#
# ModuleNotFoundError: No module named 'ydata_profiling'
