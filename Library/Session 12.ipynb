# %%
# 1.Install Seaborn in your Python environment and use it to create a histplot showing the distribution of delivery times (in minutes) for 50 Zomato food orders. Generate random data if needed.
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Generate random delivery times for 50 orders
np.random.seed(42)

delivery_times = np.random.randint(20, 61, 50)

# Create histogram
sns.histplot(delivery_times, bins=8, kde=True)

plt.title("Zomato Delivery Time Distribution")
plt.xlabel("Delivery Time (Minutes)")
plt.ylabel("Number of Orders")

plt.show()

# %%
# 2.Load the 'tips' dataset from Seaborn and create a boxplot to visualize the distribution of total bill amounts by day of the week, similar to how Zomato might analyze spending patterns across weekdays.
import seaborn as sns
import matplotlib.pyplot as plt

# Load tips dataset
tips = sns.load_dataset("tips")

# Display first 5 rows
print(tips.head())

# Create boxplot
sns.boxplot(
    x="day",
    y="total_bill",
    data=tips
)

plt.title("Total Bill Amount by Day")
plt.xlabel("Day of the Week")
plt.ylabel("Total Bill Amount ($)")

plt.show()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# 3.Simulate IPL match scores for 8 teams and use a violinplot to compare the run distributions per team. Style your plot using the 'darkgrid' Seaborn theme.
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

np.random.seed(42)

teams = [
    "CSK",
    "MI",
    "RCB",
    "KKR",
    "GT",
    "RR",
    "SRH",
    "DC"
]

# Create data
data = []

for team in teams:
    scores = np.random.randint(120, 220, 20)

    for score in scores:
        data.append([team, score])

# Convert to DataFrame
df = pd.DataFrame(data, columns=["Team", "Runs"])
# Set Seaborn theme
sns.set_theme(style="darkgrid")

# Create violin plot
plt.figure(figsize=(10, 6))

sns.violinplot(
    x="Team",
    y="Runs",
    data=df
)

plt.title("IPL Run Distribution by Team")
plt.xlabel("IPL Team")
plt.ylabel("Runs")

plt.show()

# %%
# 4.Create a countplot that displays the number of songs per genre from a list of 40 Spotify tracks, with at least 4 different genres represented.<br><br><em><strong>Hint:</strong> Use a Python list or pandas DataFrame to store your data, then plot with Seaborn.</em>
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

genres = [
    "Pop", "Rock", "Hip-Hop", "EDM",
    "Pop", "Rock", "Pop", "EDM",
    "Hip-Hop", "Rock", "Pop", "EDM",
    "Rock", "Hip-Hop", "Pop", "Pop",
    "EDM", "Rock", "Hip-Hop", "Pop",
    "Rock", "EDM", "Pop", "Hip-Hop",
    "Pop", "Rock", "EDM", "Pop",
    "Hip-Hop", "Rock", "Pop", "EDM",
    "Rock", "Pop", "Hip-Hop", "EDM",
    "Pop", "Rock", "Pop", "Hip-Hop"
]

# Create DataFrame
df = pd.DataFrame({
    "Genre": genres
})

# Countplot
sns.countplot(
    x="Genre",
    data=df
)

plt.title("Number of Spotify Songs by Genre")
plt.xlabel("Music Genre")
plt.ylabel("Number of Songs")

plt.show()

# %%
# 5.Use Seaborn's kdeplot to visualize the distribution of daily step counts for a week, as if analyzing data from a fitness app. Apply the 'whitegrid' theme and customize the plot color.
import seaborn as sns
import matplotlib.pyplot as plt

steps = [
    6500,
    8200,
    7500,
    9100,
    8800,
    10500,
    7200
]

# Set whitegrid theme
sns.set_theme(style="whitegrid")

# Create KDE plot
sns.kdeplot(
    steps,
    fill=True,
    color="green"
)

plt.title("Daily Step Count Distribution")
plt.xlabel("Number of Steps")
plt.ylabel("Density")

plt.show()
