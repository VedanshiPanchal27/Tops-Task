# %%
# 1.Given a list of delivery timestamps as strings (e.g., ['2024-06-01 14:30', '2024-06-02 09:15', '2024-06-03 20:45']), use pandas and pd.to_datetime() to convert them into datetime objects and print the result.
import pandas as pd

timestamps = [
    "2024-06-01 14:30",
    "2024-06-02 09:15",
    "2024-06-03 20:45"
]

dates = pd.to_datetime(timestamps)

print(dates)
# Out:
# DatetimeIndex(['2024-06-01 14:30:00', '2024-06-02 09:15:00',
#                '2024-06-03 20:45:00'],
#               dtype='datetime64[us]', freq=None)

# %%
# 2.Load a CSV file containing order dates from a Flipkart-style order history (column: 'order_date', format: 'YYYY-MM-DD HH:MM:SS'). Extract the year, month, and weekday for each order and add them as new columns in the DataFrame.
import pandas as pd

df = pd.read_csv("flipkart_order_history.csv")

# Convert order_date to datetime
df["order_date"] = pd.to_datetime(df["order_date"])

# Extract information
df["year"] = df["order_date"].dt.year
df["month"] = df["order_date"].dt.month
df["weekday"] = df["order_date"].dt.day_name()

print(df)
# Out:
#    order_id          order_date  year  month    weekday
# 0       101 2024-06-01 14:30:00  2024      6   Saturday
# 1       102 2024-06-02 09:15:00  2024      6     Sunday
# 2       103 2024-06-03 20:45:00  2024      6     Monday
# 3       104 2024-06-05 11:20:00  2024      6  Wednesday
# 4       105 2024-06-08 16:10:00  2024      6   Saturday
# 5       106 2024-06-10 13:00:00  2024      6     Monday
# 6       107 2024-06-15 19:30:00  2024      6   Saturday
# 7       108 2024-06-16 10:45:00  2024      6     Sunday

# %%
# 3.Set the 'order_date' column as the index of your DataFrame and use resampling to calculate the total number of orders placed each week.<br><br><em><strong>Hint:</strong> Use df.resample('W').size() after setting the datetime index.</em>
import pandas as pd

df = pd.read_csv("flipkart_order_history.csv")

df["order_date"] = pd.to_datetime(df["order_date"])

# Set order_date as index
df = df.set_index("order_date")

# Count orders each week
weekly_orders = df.resample("W").size()

print(weekly_orders)
# Out:
# order_date
# 2024-06-02    2
# 2024-06-09    3
# 2024-06-16    3
# Freq: W-SUN, dtype: int64

# %%
# 4.Suppose you have a DataFrame of Instagram posts with a 'posted_at' column in UTC. Convert these timestamps to 'Asia/Kolkata' timezone and display the first 5 converted times.
import pandas as pd

df = pd.DataFrame({
    "posted_at": [
        "2024-06-01 08:30:00",
        "2024-06-02 05:15:00",
        "2024-06-03 14:45:00",
        "2024-06-04 10:20:00",
        "2024-06-05 16:10:00"
    ]
})

# Convert to UTC datetime
df["posted_at"] = pd.to_datetime(df["posted_at"], utc=True)

# Convert UTC to India time
df["india_time"] = df["posted_at"].dt.tz_convert("Asia/Kolkata")

print(df["india_time"].head())
# Out:
# 0   2024-06-01 14:00:00+05:30
# 1   2024-06-02 10:45:00+05:30
# 2   2024-06-03 20:15:00+05:30
# 3   2024-06-04 15:50:00+05:30
# 4   2024-06-05 21:40:00+05:30
# Name: india_time, dtype: datetime64[us, Asia/Kolkata]

# %%
# 5.Create a new feature called 'is_weekend' in your DataFrame that marks True if an order was placed on Saturday or Sunday, and False otherwise.<br><br><em><strong>Constraint:</strong> Do not use any external libraries except pandas and numpy.</em>
import pandas as pd
import numpy as np

df = pd.read_csv("flipkart_order_history.csv")

df["order_date"] = pd.to_datetime(df["order_date"])

# Saturday = 5, Sunday = 6
df["is_weekend"] = df["order_date"].dt.dayofweek >= 5

print(df[["order_date", "is_weekend"]])
# Out:
#            order_date  is_weekend
# 0 2024-06-01 14:30:00        True
# 1 2024-06-02 09:15:00        True
# 2 2024-06-03 20:45:00       False
# 3 2024-06-05 11:20:00       False
# 4 2024-06-08 16:10:00        True
# 5 2024-06-10 13:00:00       False
# 6 2024-06-15 19:30:00        True
# 7 2024-06-16 10:45:00        True
