# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\sp\appdata\local\programs\python\python312\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\sp\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (2.5.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\sp\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (3.0.5)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\sp\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (3.11.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\sp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in c:\users\sp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.64.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\sp\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.2)
# Requirement already satisfied: pillow>=9 in c:\users\sp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\sp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sp\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\sp\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn) (2026.3)
# Requirement already satisfied: six>=1.5 in c:\users\sp\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# 1.Load the 'tips' dataset from Seaborn and create a pairplot to quickly visualize relationships between all numeric variables.
import seaborn as sns
import matplotlib.pyplot as plt

# Load tips dataset
tips = sns.load_dataset("tips")

# Display first 5 rows
print(tips.head())

# Create pairplot
sns.pairplot(tips)

plt.show()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# 2.Using the 'flights' dataset from Seaborn, generate a heatmap showing the correlation between months and years based on the number of passengers.<br><br><em><strong>Hint:</strong> Use pivot_table to reshape the data before plotting the heatmap.</em>
import seaborn as sns
import matplotlib.pyplot as plt

# Load flights dataset
flights = sns.load_dataset("flights")

# Create pivot table
flight_pivot = flights.pivot_table(
    index="month",
    columns="year",
    values="passengers"
)

# Create heatmap
plt.figure(figsize=(12, 8))

sns.heatmap(
    flight_pivot,
    annot=True,
    fmt="d",
    cmap="YlOrRd"
)

plt.title("Number of Passengers by Month and Year")
plt.xlabel("Year")
plt.ylabel("Month")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 18
#      14
#      15 # Create heatmap
#      16 plt.figure(figsize=(12, 8))
#      17
# ---> 18 sns.heatmap(
#      19     flight_pivot,
#      20     annot=True,
#      21     fmt="d",
#
# File c:\Users\SP\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\matrix.py:459, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     457 if square:
#     458     ax.set_aspect("equal")
# --> 459 plotter.plot(ax, cbar_ax, kwargs)
#     460 return ax
#
# File c:\Users\SP\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\matrix.py:352, in _HeatMapper.plot(self, ax, cax, kws)
#     350 # Annotate the cells with the formatted values
#     351 if self.annot:
# --> 352     self._annotate_heatmap(ax, mesh)
#
# File c:\Users\SP\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\matrix.py:260, in _HeatMapper._annotate_heatmap(self, ax, mesh)
#     258 lum = relative_luminance(color)
#     259 text_color = ".15" if lum > .408 else "w"
# --> 260 annotation = ("{:" + self.fmt + "}").format(val)
#     261 text_kwargs = dict(color=text_color, ha="center", va="center")
#     262 text_kwargs.update(self.annot_kws)
#
# ValueError: Unknown format code 'd' for object of type 'float'

# %%
# 3.Create a relplot using the 'fmri' dataset from Seaborn to visualize how the signal changes over time for different event types.

import matplotlib.pyplot as plt

# Load fmri dataset
fmri = sns.load_dataset("fmri")

# Create relplot
sns.relplot(
    data=fmri,
    x="timepoint",
    y="signal",
    hue="event",
    kind="line"
)

plt.show()

# %%
# 4.Pick any categorical column from the 'titanic' dataset (like 'class' or 'sex') and use catplot to display the survival rate for each group with confidence intervals.
import seaborn as sns
import matplotlib.pyplot as plt

# Load Titanic dataset
titanic = sns.load_dataset("titanic")

# Create catplot
sns.catplot(
    data=titanic,
    x="class",
    y="survived",
    kind="bar",
    errorbar=("ci", 95)
)

plt.title("Titanic Survival Rate by Passenger Class")
plt.xlabel("Passenger Class")
plt.ylabel("Survival Rate")

plt.show()

# %%
# 5.Use jointplot on the 'penguins' dataset to visualize the relationship between bill_length_mm and flipper_length_mm, and fit a regression line on the scatter plot.<br><br><em><strong>Hint:</strong> Set kind='reg' in jointplot for regression line.</em>
import seaborn as sns
import matplotlib.pyplot as plt

# Load penguins dataset
penguins = sns.load_dataset("penguins")

# Remove missing values
penguins = penguins.dropna(
    subset=["bill_length_mm", "flipper_length_mm"]
)

# Create jointplot with regression line
sns.jointplot(
    data=penguins,
    x="bill_length_mm",
    y="flipper_length_mm",
    kind="reg"
)

plt.show()
